# %%
# import pandas as pd

# file_path = 'Mine Log Abstract 2.csv'  

# try:
#     df = pd.read_csv(file_path, encoding='ISO-8859-1') 
# except UnicodeDecodeError:
#     print("Failed to read the file with ISO-8859-1 encoding. Trying a different encoding...")
#     df = pd.read_csv(file_path, encoding='latin1')  

# print(df.head())

# print("Column Data Types:")
# print(df.dtypes)

import pandas as pd

file_path = 'cybersec_iot_spinet_data/train_data/0a0cb191-e996-42c0-8cf4-0e359d9d51b2.csv'  

try:
    df = pd.read_csv(file_path, encoding='ISO-8859-1') 
except UnicodeDecodeError:
    print("Failed to read the file with ISO-8859-1 encoding. Trying a different encoding...")
    df = pd.read_csv(file_path, encoding='latin1')  

print(df.head())

# print("Column Data Types:")
# print(df.dtypes)
# Out:
#    SYSCALL_timestamp SYSCALL_arch SYSCALL_syscall SYSCALL_success  \
# 0                  0      aarch64            mmap             yes
# 1                  0      aarch64           clone             yes
# 2                  0      aarch64          munmap             yes
# 3                  0      aarch64           close             yes
# 4                  0      aarch64          execve             yes
#
#    SYSCALL_exit PROCESS_comm        PROCESS_exe  \
# 0  5.481085e+11      apache2  /usr/sbin/apache2
# 1  8.945580e+05      apache2  /usr/sbin/apache2
# 2  0.000000e+00      apache2  /usr/sbin/apache2
# 3  0.000000e+00      apache2  /usr/sbin/apache2
# 4  0.000000e+00           sh      /usr/bin/dash
#
#                          PROCESS_PATH CUSTOM_openFiles CUSTOM_libs  ...  \
# 0                    >systemd>apache2               []          []  ...
# 1                    >systemd>apache2               []          []  ...
# ...

# %%
# import pandas as pd

# file_path = 'Mine Log Abstract 2.csv'  

# try:
#     df = pd.read_csv(file_path, encoding='ISO-8859-1') 
# except UnicodeDecodeError:
#     print("Failed to read the file with ISO-8859-1 encoding. Trying a different encoding...")
#     df = pd.read_csv(file_path, encoding='latin1')  

# print(df.head())

# print("Column Data Types:")
# print(df.dtypes)

import pandas as pd

file_path = 'cybersec_iot_spinet_data/train_data/0a0cb191-e996-42c0-8cf4-0e359d9d51b2.csv'  

try:
    df = pd.read_csv(file_path, encoding='ISO-8859-1') 
except UnicodeDecodeError:
    print("Failed to read the file with ISO-8859-1 encoding. Trying a different encoding...")
    df = pd.read_csv(file_path, encoding='latin1')  

print(df.head())

# print("Column Data Types:")
# print(df.dtypes)
# Out:
#    SYSCALL_timestamp SYSCALL_arch SYSCALL_syscall SYSCALL_success  \
# 0                  0      aarch64            mmap             yes
# 1                  0      aarch64           clone             yes
# 2                  0      aarch64          munmap             yes
# 3                  0      aarch64           close             yes
# 4                  0      aarch64          execve             yes
#
#    SYSCALL_exit PROCESS_comm        PROCESS_exe  \
# 0  5.481085e+11      apache2  /usr/sbin/apache2
# 1  8.945580e+05      apache2  /usr/sbin/apache2
# 2  0.000000e+00      apache2  /usr/sbin/apache2
# 3  0.000000e+00      apache2  /usr/sbin/apache2
# 4  0.000000e+00           sh      /usr/bin/dash
#
#                          PROCESS_PATH CUSTOM_openFiles CUSTOM_libs  ...  \
# 0                    >systemd>apache2               []          []  ...
# 1                    >systemd>apache2               []          []  ...
# ...
